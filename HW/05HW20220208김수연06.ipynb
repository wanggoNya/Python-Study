# %%
#231
def n_plus_1 (n) :
  result = n+1
n_plus_1(3)
print(result)

# name 'result' is not defined,
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\SOOYEO~1\AppData\Local\Temp/ipykernel_12292/415782606.py in <module>
#       3   result = n+1
#       4 n_plus_1(3)
# ----> 5 print(result)
#       6
#       7 # name 'result' is not defined,
#
# NameError: name 'result' is not defined

# %%
#232
def make_url(key):
    return key
    
naver='www.naver.com'
print(make_url(naver))


#Answer
def make_url(key):
    return "www."+key+".com"

print(make_url("naver"))
# Out:
# www.naver.com
# www.naver.com

# %%
#233
# make_list("abcd")


def make_list(li):
    for i in li:
        print(i,end='')
word = ['a', 'b', 'c', 'd']
make_list(word)
        
#Answer
def make_list(li):
    ans = []
    for i in li:
        ans.append(i)
    return ans
print(make_list("abcd"))
# Out:
# abcd['a', 'b', 'c', 'd']

# %%
#234
num2 = []
def pickup_even(num):
    for i in num:
        if i%2 == 0:
            num2.insert(-1,i)
    print (num2)
pickup_even([3, 4, 5, 6, 7, 8])
# Out:
# [6, 8, 4]

# %%
#235
def convert_int(str):
    str1 = int(str.replace(',' , ''))
    print(str1)

convert_int("1,234,567")
# Out:
# 1234567

# %%
#236
def 함수(num) :
 return num + 4
a = 함수(10)
b = 함수(a)
c = 함수(b)
print(c)
#num 함수에 4를 더한 값을 결과값으로 설정하고 a는 함수에 10을 넣은 것이므로 a는 14, b는 18, c는 따라서 22
# Out:
# 22

# %%
#237
def 함수(num) :
 return num + 4
c = 함수(함수(함수(10)))
print(c)
# 가장먼저 10을 넣으면 14, 두번째는 18, 마지막은 22므로 결과값은 22
# Out:
# 22

# %%
#238
def 함수1(num) :
 return num + 4
def 함수2(num) :
 return num * 10
a = 함수1(10)
c = 함수2(a)
print(c)
# a는 14, c는 280, 결과값은 140

# %%
#239
def 함수1(num) :
 return num + 4
def 함수2(num) :
 num = num + 2
 return 함수1(num)
c = 함수2(10)
print(c)
# 함수2(10)은 12, 함수2의 리턴값은 함수1에 12를 넣으므로 16, 결과값은 16!

# %%
#240
def 함수0(num) :
 return num * 2

def 함수1(num) :
 return 함수0(num + 2)

def 함수2(num) :
    num = num + 10
    return 함수1(num)

c = 함수2(2)
print(c)
#함수2에 2를 넣으면 12, 리턴값은 함수0에 14를 넣으므로 28.결과값 28

# %%
#296
per = ["10.31", "", "8.00"]
try:
    for i in per:
        print(float(i))
except:
    i = 0
print(float(i))

#Answer
print('-------')

for i in per:
    try:
        print(float(i))
    except:
        print(0)
# Out:
# 10.31
# 0.0
# -------
# 10.31
# 0
# 8.0

# %%
#297
per = ["10.31", "", "8.00"]
num = []
try:
    for n in per:
        i = float(n)
        num.insert(-1,i)
except:
    i = 0
num.insert(-1,i)
print(num)
