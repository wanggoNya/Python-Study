# %%
#001
print('Hello World')
# Out:
# Hello World

# %%
#002
print('Mary\'s cosmetics')
print("Mary's cosmetics")
# Out:
# Mary's cosmetics
# Mary's cosmetics

# %%
#003
print('신씨가 소리질렀다. \"도둑이야\".')
print('신씨가 소리질렀다. "도둑이야".')
# Out:
# 신씨가 소리질렀다. "도둑이야".
# 신씨가 소리질렀다. "도둑이야".

# %%
#004
print('"C:\windows\"')
# Out:
# "C:\windows"

# %%
#005
print("안녕하세요.\n 만나서\t\t 반갑습니다.")
## \n은 줄바꿈, \t는 띄어쓰기를 의미한다.
# Out:
# 안녕하세요.
#  만나서		 반갑습니다.

# %%
#006
print ("오늘은", "일요일")
## 오늘은과 일요일 사이 띄어쓰기 한 칸이 존재

# %%
#007
print('naver;kakao;sk;samsung')
# Out:
# naver;kakao;sk;samsung

# %%
#008
print('naver/kakao/sk/samsung')
# Out:
# naver/kakao/sk/samsung

# %%
#009
print("first", end = ' ');print("second")
# Out:
# first second

# %%
#010
div = 5/3
print(div)
# Out:
# 1.6666666666666667

# %%
#011
sam = 50000
sto = 10
pri = int(sam*sto)
print(f'삼성전자의 총 평가금액은 {pri}원 입니다.')
# Out:
# 삼성전자의 총 평가금액은 500000원 입니다.

# %%
#012
cap = 290000000000000
now = 50000
per = 15.79

# %%
#013
s = "hello"
t = "python"
print(f'{s}! {t}')
# Out:
# hello! python

# %%
#014
a = 2
b = 2
c = 3
ans = float(a+a*3)
print(ans)
# Out:
# 8.0

# %%
#015
a = "132"
print(type(a))
#string이다.
# Out:
# <class 'str'>

# %%
#016
num_str = int("720")
print(type(num_str))
# Out:
# <class 'int'>

# %%
#017
num = 100
num = str(100)
num = "100"
print(type(num))
# Out:
# <class 'str'>

# %%
#018
num = float("15.79")
print(type(num))
# Out:
# <class 'float'>

# %%
#019
# year = int(2020)
# last3 = int(year-3)
# last2 = int(year-2)
# last1 = int(year-1)
# print(f'3년 전은 {last3}년이고, 재작년은 {last2}년이며, 작년은 {last1}년 입니다.')

year = "2020"
print(int(year)-3)
print(int(year)-3)
print(int(year)-1)
# Out:
# 2017
# 2017
# 2019

# %%
#020
# air = 48584
# month = float(input("무이자 36개월입니다. 몇 개월로 결제하시겠습니까?"))
# price = float((air)*(month))
# print(f'에어컨의 총 금액은 {price}원입니다.')

월 = 48584
총금액 = 월 * 36
print(총금액)
# Out:
# 1749024
