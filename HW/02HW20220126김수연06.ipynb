# %%
#051
movie_rank = ["닥터 스트레인지","스플릿","럭키"]


#052
movie_rank.append("배트맨")

#053
movie_rank.insert(1,"슈퍼맨")

#054
del movie_rank[3]

#055
del movie_rank[2:]


print(movie_rank)
# Out:
# ['닥터 스트레인지', '슈퍼맨']

# %%
#056
lang1 = ["c", "c++", "JAVA"]
lang2 = ["Python", "Go","C#"]

langs = lang1 + lang2
print(langs)
# Out:
# ['c', 'c++', 'JAVA', 'Python', 'Go', 'C#']

# %%
#057
nums = [1,2,3,4,5,6,7]
print(f'max : {max(nums)}')
print(f'min : {min(nums)}')
# Out:
# max : 7
# min : 1

# %%
#058
nums = [1,2,3,4,5]
print(sum(nums))
# Out:
# 15

# %%
#059
cook = ["피자", "김밥", "만두", "양념치킨", "족발", "피자", "김치만두", 
"쫄면", "쏘세지", "라면", "팥빙수", "김치전"]
print(len(cook))
# Out:
# 12

# %%
#060
nums = [1, 2, 3, 4, 5]
avg = sum(nums) / len(nums)
print(avg)
# Out:
# 3.0

# %%
#121
word = input("영문자를 입력하세요")
type = islower(word)
ans = ""

if type = True:
  ans = "소문자"
else:
  ans = "대문자"

print(ans)
# Out:
#   File "<ipython-input-36-821250d3e917>", line 6
#     if type = True:
#             ^
# SyntaxError: invalid syntax

# %%
#122
score = int(input("점수를 입력하세요."))
grade = ""

if score > 80 :
  grade = "A"
elif score > 60 :
  grade = "B"
elif score > 40 :
  grade = "C"
elif score > 20 :
  grade = "D"

else :
  grade = "E"

print(f'당신의 학점은 {grade}입니다.')
# Out:
# 점수를 입력하세요.123
# 당신의 학점은 A입니다.

# %%
#123
money = float(input("액수를 입력하세요."))
type = input("단위를 입력하세요.")
# per = (money[0:])
won = ""
if "달러" in type:
  won =float (money * 1167)
if "엔" in type:
  won = float(money * 1.096)
if "유로" in type:
  won = float(money * 1268)
if "위안" in type:
  won = float(money * 171)

print(f'{won} 원')
# Out:
# 액수를 입력하세요.123
# 단위를 입력하세요.유로
# 155964.0 원

# %%
#124
num1 = int(input("정수1을 입력하세요"))
num2 = int(input("정수2을 입력하세요"))
num3 = int(input("정수3을 입력하세요"))
big = ""
if num1<num3 and num2<num3:
  big = num3
elif num1<num2:
  big = num2
else :
  big = num1

print(big)
# Out:
# 정수1을 입력하세요125
# 정수2을 입력하세요243
# 정수3을 입력하세요213
# 243

# %%
#125
pn = (input("핸드폰 번호를 입력하세요 >>  "))
num = (pn[0:3])
type = ""
if "011" in num:
  type = "SKT"
elif "016" in num:
  type = "KT"
elif "019" in num:
  type = "LGU"
else :
  type = "알수없음"

print(f'당신은 {type} 사용자입니다.')
# Out:
# 핸드폰 번호를 입력하세요 >>  016123
# 당신은 KT 사용자입니다.

# %%
#126
home = (input("우편번호 : "))
partnum = int((home[2]))
part = ""
if partnum < 3:
  part = "강북구"
elif partnum < 6 :
  part = "도봉구"
else :
  part = "노원구"

print(part)
# Out:
# 우편번호 : 123
# 도봉구

# %%
#127
num = (input("주민번호를 입력하세요 ex> xxxxxx-xxxxxxx "))
peo = int((num[-7]))
s = ""

if 1 or 3 in peo:
  s = "남성"
elif 2 or 4 in peo:
  s = "여성"
else :
  print("다시 입력하세요.")

print(s)
# Out:
# 주민번호를 입력하세요 ex> xxxxxx-xxxxxxx 123456-1234567
# 남성

# %%
#128
num = (input("주민번호를 입력하세요 ex> xxxxxx-xxxxxxx "))
peo = int((num[9:11]))
ct = ""
if peo > 8:
  ct = "서울 입니다."
else :
  ct = "서울이 아닙니다."

print(ct)
# Out:
# 주민번호를 입력하세요 ex> xxxxxx-xxxxxxx 123456-0022222
# 서울 입니다.

# %%
#129
num = int(input("주민번호를 입력하세요 ex> xxxxxx-xxxxxxx "))
cal1 = int(num[0]*2 + num[1]*3 + num[2]*4 + num[3]*5 + num[4]*6 + num[5]*7 + num[6]*8 + num[8]*9 + num[9]*2 + num[10]*3 + num[11]*4 + num[12]*5)
cal2 = cal1 % 11
last = 11 - cal2
num1 = ""
if last = int(num[-1]):
  num1 = "유효"
else:
  num1 = "무효"

  print(f'{num1}한 주민등록번호입니다.')
# Out:
#   File "<ipython-input-1-5a1d6895b30e>", line 7
#     if last = int(num[-1]):
#             ^
# SyntaxError: invalid syntax

# %%
#130
import requests
btc = 
requests.get("https://api.bithumb.com/public/ticker/").json()['data']
