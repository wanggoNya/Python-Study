# %%
#091
inventory = {
    "메로나" : [300,20],
    "비비빅" : [400,3],
    "죠스바" : [250,100]
}

#092
print(f'{inventory["메로나"][0]} 원')

#093
print(f'{inventory["메로나"][1]} 개')

#094
inventory["월드콘"] = [500,7]

print(inventory)
# Out:
# 300 원
# 20 개
# {'메로나': [300, 20], '비비빅': [400, 3], '죠스바': [250, 100], '월드콘': [500, 7]}

# %%
#096
icecream = {
    '탱크보이': 1200, 
    '폴라포': 1200, 
    '빵빠레': 1800, 
    '월드콘': 1500, 
    '메로나': 1000
}
li = list(icecream.keys()) #딕셔너리 keys 를 리스트로 생성
print(li)
li2 = list(icecream.values()) #딕셔너리 values 를 리스트로 생성
print(li2)
# Out:
# ['탱크보이', '폴라포', '빵빠레', '월드콘', '메로나']
# [1200, 1200, 1800, 1500, 1000]

# %%
#097
icecream = {
    '탱크보이': 1200, 
    '폴라포': 1200, 
    '빵빠레': 1800, 
    '월드콘': 1500, 
    '메로나': 1000
}
sum(icecream.values())
# Out:
# 6700

# %%
#098
icecream = {'탱크보이': 1200, '폴라포': 1200, '빵빠레': 1800, '월드콘': 1500, '메로나': 1000}
new_product = {'팥빙수':2700, '아맛나':1000}
icecream.update(new_product)
print(icecream)
# Out:
# {'탱크보이': 1200, '폴라포': 1200, '빵빠레': 1800, '월드콘': 1500, '메로나': 1000, '팥빙수': 2700, '아맛나': 1000}

# %%
#099
keys = ("apple", "pear", "peach")
vals = (300, 250, 400)
dict(zip(keys, vals))
# Out:
# {'apple': 300, 'peach': 400, 'pear': 250}

# %%
#100
date = ['09/05', '09/06', '09/07', '09/08', '09/09']
close_price = [10500, 10300, 10100, 10800, 11000]
close_table = dict(zip(date, close_price))
print(close_table)
# Out:
# {'09/05': 10500, '09/06': 10300, '09/07': 10100, '09/08': 10800, '09/09': 11000}

# %%
#151
li = [3, -20, -3, 44]
for i in li[0:]:
  if i < 0:
    print(i)
# Out:
# -20
# -3

# %%
#152
li =  [3, 100, 23, 44]
for i in li[0:]:
  if i %3 == 0:
    print(i)
# Out:
# 3

# %%
#153
li = [13, 21, 12, 14, 30, 18]
for i in li[0:]:
  if i < 21 and i %3 == 0:
    print(i)
# Out:
# 12
# 18

# %%
#154
li = ["I", "study", "python", "language", "!"]
li2 = ''
for i in li[0:]:
  li2 = i
  print(li2)
# Out:
# I
# study
# python
# language
# !

# %%
#155
li = ["A", "b", "c", "D"]
for i in li[0:]:
  if i.isupper():
    print(i)
# Out:
# A
# D

# %%
#156
li = ["A", "b", "c", "D"]
for i in li[0:]:
  if i.islower():
    print(i)
# Out:
# b
# c

# %%
#157
li = ['dog', 'cat', 'parrot']
for i in li[0:]:
  print(f'{i[0:1].upper()}{i[1:]}')
# Out:
# Dog
# Cat
# Parrot

# %%
#158
li = ['hello.py', 'ex01.py', 'intro.hwp']
for i in li[0:]:
  li2 = i.split('.')
  for li3 in li2[0:1]:
    print(li3)
# Out:
# hello
# ex01
# intro

# %%
#159
li = ['intra.h', 'intra.c', 'define.h', 'run.py']
for i in li[0:]:
  li2 = i.split('.')
  for li3 in li2[-1:]:
    if 'h' in li3:
      print(i)
# Out:
# intra.h
# define.h

# %%
#160
li = ['intra.h', 'intra.c', 'define.h', 'run.py']
for i in li[0:]:
  li2 = i.split('.')
  for li3 in li2[-1:]:
    if 'h' in li3 or 'c' in li3:
      print(i)
# Out:
# intra.h
# intra.c
# define.h
