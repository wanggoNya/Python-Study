# %%
#211
def 함수(문자열) :
 print(문자열)
함수("안녕")
함수("Hi")
# Out:
# 안녕
# Hi

# %%
#212
def 함수(a, b) :
 print(a + b)
함수(3, 4)
함수(7, 8)
# Out:
# 7
# 15

# %%
#213
def 함수(문자열) :
 print(문자열)
함수() #괄호 안에 입력값이 없어서 에러가 난다.
# TypeError: 함수() missing 1 required positional argument: '문자열'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-5b11d5057976> in <module>()
#       2 def 함수(문자열) :
#       3  print(문자열)
# ----> 4 함수() #괄호 안에 입력값이 없어서 에러가 난다.
#       5 # TypeError: 함수() missing 1 required positional argument: '문자열'
#
# TypeError: 함수() missing 1 required positional argument: '문자열'

# %%
#214
def 함수(a, b) :
 print(a + b)
함수("안녕", 3) # "안녕"은 int가 아닌 string이므로 덧셈이 적용되지 않음
# TypeError: must be str, not int

# %%
#215
a = input("문자열 입력")
def print_with_smile(a):
  print(a + ":D")
print_with_smile(a)

# %%
#216
a = input("문자열 입력")
def print_with_smile(a):
  print(a + ":D")
print_with_smile(a)

# %%
#217
a = int(input("가격입력"))
def print_upper_price(a):
  print(a * 0.3)
print_upper_price(a)

# %%
#218
a = int(input("a 입력"))
b = int(input("b 입력"))
def print_sum(a,b):
  print(a+b)
print_sum(a,b)

# %%
#219
a = int(input("a 입력"))
b = int(input("b 입력"))
def print_arithmetic_operation(a,b):
  print(a+b)
  print(a-b)
  print(a*b)
  print(a/b)
print_arithmetic_operation(a,b)

# %%
#220
a = int(input("a 입력"))
b = int(input("b 입력"))
c = int(input("c 입력"))
def print_max(a,b,c):
  if (a > b) and (a > c):
    print(a)
  elif (b > c):
    print(b)
  else:
    print(c)
print_max(a,b,c)

# %%
#221
def print_reverse():
  return "python"
re = print_reverse()
print(re[::-1])

# %%
#222
def print_score(ave):
  return sum(ave[0:])/len(ave)
a = [1,2,3]
result = print_score(a)
print(result)
# Out:
# 2.0

# %%
#223
def print_even (even):
    for i in even[0:]:
        if (i % 2) == 0:
            print(i)
    # return i
print(print_even([1,3,2,10,12,15]))

# %%
#224
def print_keys(keys):
    return keys.keys()
result = print_keys({"이름":"김말똥", "나이":30, "성별":0})
print(result)

# %%
#225
def print_value_by_key (name, val):
    return name.values[val]

my_dict = {"10/26" : [100, 130, 100, 100],
 "10/27" : [10, 12, 10, 11]}
result = print_value_by_key(my_dict,"10/26")
print(result)

# %%
#226

# %%
#227

# %%
#228

# %%
#229

# %%
#230
