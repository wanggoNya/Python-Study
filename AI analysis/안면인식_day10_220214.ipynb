# %%
# Client ID      : Qyj8LppmG3_kwUQiHNeL
# Client Secret : hq0M33c3h6


import os         # 운영체제 접근
import sys        # 시스템 접근
import requests # 웹 접근

client_id = "Qyj8LppmG3_kwUQiHNeL"
client_secret = "hq0M33c3h6"


url = "https://openapi.naver.com/v1/vision/face"    #얼굴감지
#url = "https://openapi.naver.com/v1/vision/celebrity" # 유명인 얼굴인식


files = {'image': open('image3.jpg', 'rb')} # 사진 파일이름

headers = {'X-Naver-Client-Id': client_id, 'X-Naver-Client-Secret': client_secret }
response = requests.post(url,  files=files, headers=headers)

rescode = response.status_code
if(rescode==200):
    print (response.text)
else:
    print("Error Code:" + rescode)
# Out:
# {"info":{"size":{"width":509,"height":339},"faceCount":5},"faces":[{"roi":{"x":308,"y":128,"width":67,"height":67},"landmark":{"leftEye":{"x":327,"y":141},"rightEye":{"x":358,"y":147},"nose":{"x":340,"y":157},"leftMouth":{"x":322,"y":168},"rightMouth":{"x":356,"y":173}},"gender":{"value":"female","confidence":0.999081},"age":{"value":"22~26","confidence":0.097743},"emotion":{"value":"smile","confidence":0.836692},"pose":{"value":"frontal_face","confidence":0.983307}},{"roi":{"x":193,"y":40,"width":33,"height":33},"landmark":{"leftEye":{"x":200,"y":47},"rightEye":{"x":216,"y":48},"nose":{"x":209,"y":58},"leftMouth":{"x":200,"y":63},"rightMouth":{"x":214,"y":64}},"gender":{"value":"male","confidence":0.998204},"age":{"value":"29~33","confidence":0.609909},"emotion":{"value":"smile","confidence":0.928663},"pose":{"value":"frontal_face","confidence":0.617717}},{"roi":{"x":131,"y":31,"width":36,"height":36},"landmark":{"leftEye":{"x":140,"y":40},"rightEye":{"x":158,"y":40},"nose":{"x":150,"y":48},"leftMouth":{"x":142,"y":56},"rightMouth":{"x":157,"y":56}},"gender":{"value":"female","confidence":0.999985},"age":{"value":"15~19","confidence":0.016219},"emotion":{"value":"laugh","confidence":0.718304},"pose":{"value":"frontal_face","confidence":0.996171}},{"roi":{"x":236,"y":158,"width":61,"height":61},"landmark":null,"gender":{"value":"male","confidence":0.667295},"age":{"value":"37~41","confidence":0.0225428},"emotion":{"value":"talking","confidence":0.989713},"pose":{"value":"false_face","confidence":0.988269}},{"roi":{"x":258,"y":191,"width":28,"height":28},"landmark":null,"gender":{"value":"child","confidence":0.563587},"age":{"value":"17~21","confidence":0.0788138},"emotion":{"value":"neutral","confidence":0.853473},"pose":{"value":"false_face","confidence":0.834868}}]}

# %%
import json

parsed = json.loads(response.text)

type(parsed)
# Out:
# dict

# %%
print(parsed)
# Out:
# {'info': {'size': {'width': 509, 'height': 339}, 'faceCount': 5}, 'faces': [{'roi': {'x': 308, 'y': 128, 'width': 67, 'height': 67}, 'landmark': {'leftEye': {'x': 327, 'y': 141}, 'rightEye': {'x': 358, 'y': 147}, 'nose': {'x': 340, 'y': 157}, 'leftMouth': {'x': 322, 'y': 168}, 'rightMouth': {'x': 356, 'y': 173}}, 'gender': {'value': 'female', 'confidence': 0.999081}, 'age': {'value': '22~26', 'confidence': 0.097743}, 'emotion': {'value': 'smile', 'confidence': 0.836692}, 'pose': {'value': 'frontal_face', 'confidence': 0.983307}}, {'roi': {'x': 193, 'y': 40, 'width': 33, 'height': 33}, 'landmark': {'leftEye': {'x': 200, 'y': 47}, 'rightEye': {'x': 216, 'y': 48}, 'nose': {'x': 209, 'y': 58}, 'leftMouth': {'x': 200, 'y': 63}, 'rightMouth': {'x': 214, 'y': 64}}, 'gender': {'value': 'male', 'confidence': 0.998204}, 'age': {'value': '29~33', 'confidence': 0.609909}, 'emotion': {'value': 'smile', 'confidence': 0.928663}, 'pose': {'value': 'frontal_face', 'confidence': 0.617717}}, {'roi': {'x': 131, 'y': 31, 'width': 36, 'height': 36}, 'landmark': {'leftEye': {'x': 140, 'y': 40}, 'rightEye': {'x': 158, 'y': 40}, 'nose': {'x': 150, 'y': 48}, 'leftMouth': {'x': 142, 'y': 56}, 'rightMouth': {'x': 157, 'y': 56}}, 'gender': {'value': 'female', 'confidence': 0.999985}, 'age': {'value': '15~19', 'confidence': 0.016219}, 'emotion': {'value': 'laugh', 'confidence': 0.718304}, 'pose': {'value': 'frontal_face', 'confidence': 0.996171}}, {'roi': {'x': 236, 'y': 158, 'width': 61, 'height': 61}, 'landmark': None, 'gender': {'value': 'male', 'confidence': 0.667295}, 'age': {'value': '37~41', 'confidence': 0.0225428}, 'emotion': {'value': 'talking', 'confidence': 0.989713}, 'pose': {'value': 'false_face', 'confidence': 0.988269}}, {'roi': {'x': 258, 'y': 191, 'width': 28, 'height': 28}, 'landmark': None, 'gender': {'value': 'child', 'confidence': 0.563587}, 'age': {'value': '17~21', 'confidence': 0.0788138}, 'emotion': {'value': 'neutral', 'confidence': 0.853473}, 'pose': {'value': 'false_face', 'confidence': 0.834868}}]}

# %%
print(json.dumps(parsed, indent= 4))
# Out:
# {
#     "info": {
#         "size": {
#             "width": 509,
#             "height": 339
#         },
#         "faceCount": 5
#     },
#     "faces": [
#         {
#             "roi": {
#                 "x": 308,
#                 "y": 128,
#                 "width": 67,
#                 "height": 67
#             },
#             "landmark": {
#                 "leftEye": {
#                     "x": 327,
#                     "y": 141
#                 },
#                 "rightEye": {
#                     "x": 358,
#                     "y": 147
#                 },
#                 "nose": {
#                     "x": 340,
#                     "y": 157
#                 },
#                 "leftMouth": {
#                     "x": 322,
#                     "y": 168
#                 },
#                 "rightMouth": {
#                     "x": 356,
#                     "y": 173
#                 }
#             },
#             "gender": {
#                 "value": "female",
#                 "confidence": 0.999081
#             },
#             "age": {
#                 "value": "22~26",
#                 "confidence": 0.097743
#             },
#             "emotion": {
#                 "value": "smile",
#                 "confidence": 0.836692
#             },
#             "pose": {
#                 "value": "frontal_face",
#                 "confidence": 0.983307
#             }
#         },
#         {
#             "roi": {
#                 "x": 193,
#                 "y": 40,
#                 "width": 33,
#                 "height": 33
#             },
#             "landmark": {
#                 "leftEye": {
#                     "x": 200,
#                     "y": 47
#                 },
#                 "rightEye": {
#                     "x": 216,
#                     "y": 48
#                 },
#                 "nose": {
#                     "x": 209,
#                     "y": 58
#                 },
#                 "leftMouth": {
#                     "x": 200,
#                     "y": 63
#                 },
#                 "rightMouth": {
#                     "x": 214,
#                     "y": 64
#                 }
#             },
#             "gender": {
#                 "value": "male",
#                 "confidence": 0.998204
#             },
#             "age": {
#                 "value": "29~33",
#                 "confidence": 0.609909
#             },
#             "emotion": {
#                 "value": "smile",
#                 "confidence": 0.928663
#             },
#             "pose": {
#                 "value": "frontal_face",
#                 "confidence": 0.617717
#             }
#         },
#         {
#             "roi": {
#                 "x": 131,
#                 "y": 31,
#                 "width": 36,
#                 "height": 36
#             },
#             "landmark": {
#                 "leftEye": {
#                     "x": 140,
#                     "y": 40
#                 },
#                 "rightEye": {
#                     "x": 158,
#                     "y": 40
#                 },
#                 "nose": {
#                     "x": 150,
#                     "y": 48
#                 },
#                 "leftMouth": {
#                     "x": 142,
#                     "y": 56
#                 },
#                 "rightMouth": {
#                     "x": 157,
#                     "y": 56
#                 }
#             },
#             "gender": {
#                 "value": "female",
#                 "confidence": 0.999985
#             },
#             "age": {
#                 "value": "15~19",
#                 "confidence": 0.016219
#             },
#             "emotion": {
#                 "value": "laugh",
#                 "confidence": 0.718304
#             },
#             "pose": {
#                 "value": "frontal_face",
#                 "confidence": 0.996171
#             }
#         },
#         {
#             "roi": {
#                 "x": 236,
#                 "y": 158,
#                 "width": 61,
#                 "height": 61
#             },
#             "landmark": null,
#             "gender": {
#                 "value": "male",
#                 "confidence": 0.667295
#             },
#             "age": {
#                 "value": "37~41",
#                 "confidence": 0.0225428
#             },
#             "emotion": {
#                 "value": "talking",
#                 "confidence": 0.989713
#             },
#             "pose": {
#                 "value": "false_face",
#                 "confidence": 0.988269
#             }
#         },
#         {
#             "roi": {
#                 "x": 258,
#                 "y": 191,
#                 "width": 28,
#                 "height": 28
#             },
#             "landmark": null,
#             "gender": {
#                 "value": "child",
#                 "confidence": 0.563587
#             },
#             "age": {
#                 "value": "17~21",
#                 "confidence": 0.0788138
#             },
#             "emotion": {
#                 "value": "neutral",
#                 "confidence": 0.853473
#             },
#             "pose": {
#                 "value": "false_face",
#                 "confidence": 0.834868
#             }
#         }
#     ]
# }

# %%
parsed.keys()
# Out:
# dict_keys(['info', 'faces'])

# %%
print(parsed['info'])
# Out:
# {'size': {'width': 509, 'height': 339}, 'faceCount': 5}

# %%
print(parsed['faces'])
# Out:
# [{'roi': {'x': 308, 'y': 128, 'width': 67, 'height': 67}, 'landmark': {'leftEye': {'x': 327, 'y': 141}, 'rightEye': {'x': 358, 'y': 147}, 'nose': {'x': 340, 'y': 157}, 'leftMouth': {'x': 322, 'y': 168}, 'rightMouth': {'x': 356, 'y': 173}}, 'gender': {'value': 'female', 'confidence': 0.999081}, 'age': {'value': '22~26', 'confidence': 0.097743}, 'emotion': {'value': 'smile', 'confidence': 0.836692}, 'pose': {'value': 'frontal_face', 'confidence': 0.983307}}, {'roi': {'x': 193, 'y': 40, 'width': 33, 'height': 33}, 'landmark': {'leftEye': {'x': 200, 'y': 47}, 'rightEye': {'x': 216, 'y': 48}, 'nose': {'x': 209, 'y': 58}, 'leftMouth': {'x': 200, 'y': 63}, 'rightMouth': {'x': 214, 'y': 64}}, 'gender': {'value': 'male', 'confidence': 0.998204}, 'age': {'value': '29~33', 'confidence': 0.609909}, 'emotion': {'value': 'smile', 'confidence': 0.928663}, 'pose': {'value': 'frontal_face', 'confidence': 0.617717}}, {'roi': {'x': 131, 'y': 31, 'width': 36, 'height': 36}, 'landmark': {'leftEye': {'x': 140, 'y': 40}, 'rightEye': {'x': 158, 'y': 40}, 'nose': {'x': 150, 'y': 48}, 'leftMouth': {'x': 142, 'y': 56}, 'rightMouth': {'x': 157, 'y': 56}}, 'gender': {'value': 'female', 'confidence': 0.999985}, 'age': {'value': '15~19', 'confidence': 0.016219}, 'emotion': {'value': 'laugh', 'confidence': 0.718304}, 'pose': {'value': 'frontal_face', 'confidence': 0.996171}}, {'roi': {'x': 236, 'y': 158, 'width': 61, 'height': 61}, 'landmark': None, 'gender': {'value': 'male', 'confidence': 0.667295}, 'age': {'value': '37~41', 'confidence': 0.0225428}, 'emotion': {'value': 'talking', 'confidence': 0.989713}, 'pose': {'value': 'false_face', 'confidence': 0.988269}}, {'roi': {'x': 258, 'y': 191, 'width': 28, 'height': 28}, 'landmark': None, 'gender': {'value': 'child', 'confidence': 0.563587}, 'age': {'value': '17~21', 'confidence': 0.0788138}, 'emotion': {'value': 'neutral', 'confidence': 0.853473}, 'pose': {'value': 'false_face', 'confidence': 0.834868}}]

# %%
parsed['faces'][4]
# Out:
# {'age': {'confidence': 0.0788138, 'value': '17~21'},
#  'emotion': {'confidence': 0.853473, 'value': 'neutral'},
#  'gender': {'confidence': 0.563587, 'value': 'child'},
#  'landmark': None,
#  'pose': {'confidence': 0.834868, 'value': 'false_face'},
#  'roi': {'height': 28, 'width': 28, 'x': 258, 'y': 191}}

# %%
import matplotlib.pyplot as plt          # 사진(그림) 관련 기본 모듈
import matplotlib.image as mpimg     # 사진 읽어오는 모듈
import matplotlib.patches as patches  # 사진 수정 관련 모듈

img = mpimg.imread('image3.jpg')     # 사진 읽어오기
fig, ax = plt.subplots(figsize=(10,10))                      # 사진을 표시할 액자틀과 사진틀 설정
ax.imshow(img)                               # 사진틀에 사진 삽입 

x,y,w,h = parsed['faces'][0]['roi'].values() # 인식한 얼굴의 roi 위치정보를 변수로 할당
age , age_conf= parsed['faces'][0]['age'].values()
gender, gender_conf = parsed['faces'][0]['gender'].values()

re_face = patches.Rectangle((x,y),w,h, facecolor='none', edgecolor='r')  # 그 위치에 사각형을 표시 정보

anno = gender + ', ' + age
plt.text(x,y, anno, color='blue')

ax.add_patch(re_face)                         # 기본 사진에 사각형 정보를 올려 수정

# %%
import matplotlib.pyplot as plt          # 사진(그림) 관련 기본 모듈
import matplotlib.image as mpimg     # 사진 읽어오는 모듈
import matplotlib.patches as patches  # 사진 수정 관련 모듈

img = mpimg.imread('image3.jpg')     # 사진 읽어오기
fig, ax = plt.subplots(figsize=(10,10))                      # 사진을 표시할 액자틀과 사진틀 설정
ax.imshow(img)                               # 사진틀에 사진 삽입 

for each in parsed['faces']:
  x,y,w,h = each['roi'].values() # 인식한 얼굴의 roi 위치정보를 변수로 할당
  re_face = patches.Rectangle((x,y),w,h, facecolor='none', edgecolor='r')  # 그 위치에 사각형을 표시 정보
  ax.add_patch(re_face)

# %%
parsed['faces'][0]

# 각 사람의 얼굴 아래(오른쪽) 성별, 나이
# Out:
# {'age': {'confidence': 0.097743, 'value': '22~26'},
#  'emotion': {'confidence': 0.836692, 'value': 'smile'},
#  'gender': {'confidence': 0.999081, 'value': 'female'},
#  'landmark': {'leftEye': {'x': 327, 'y': 141},
#   'leftMouth': {'x': 322, 'y': 168},
#   'nose': {'x': 340, 'y': 157},
#   'rightEye': {'x': 358, 'y': 147},
#   'rightMouth': {'x': 356, 'y': 173}},
#  'pose': {'confidence': 0.983307, 'value': 'frontal_face'},
#  'roi': {'height': 67, 'width': 67, 'x': 308, 'y': 128}}

# %%
import matplotlib.patches as patches  # 사진(그림) 수정 관련 모듈
import matplotlib.image as mpimg      # 사진 읽어오는 모듈
import matplotlib.pyplot as plt       # 사진 수정 관련 모듈


img = mpimg.imread('image3.jpg')     # 사진 읽어오기
fig, ax = plt.subplots()             # 사진을 표시할 액자틀과 사진틀 설정
ax.imshow(img)                       # 사진틀에 사진 삽입


for each in parsed['faces']:
  x,y,w,h = each['roi'].values()  # 인식한 얼굴의 roi 위치정보를 변수로 할당
  
  age, age_cong = each['age'].values()
  gender, gender_cong = each['gender'].values()

  re_face = patches.Rectangle((x,y),w,h, facecolor='none', edgecolor='r') # 그 위치에 사각형을 표시 정보

  anno = gender + ', ' + age
  plt.text(x,y+h+20,anno,color='blue')
  
  ax.add_patch(re_face) # 기본 사진에 사각형 정보를 올려 수정
